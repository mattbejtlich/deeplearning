# %% [markdown]
# ## Text Generation with LSTM using Lord of the Rings: The Two Towers corpus

# %% [markdown]
# https://medium.com/@matthewbejtlich/text-generation-with-lstm-lord-of-the-rings-the-two-towers-99e977b8a5e8

# %% [markdown]
# ## Model 1

# %% [markdown]
# This is the first model for my text generation with LSTM. Please see Text_Generation_Model_2.ipynb for Model 2.

# %%
import keras
keras.__version__
# Out:
# '2.1.5'

# %% [markdown]
# ### Load Lord of Rings: The Two Towers corpus

# %%
import numpy as np

text = open('data/Lordoftherings2.txt').read().lower()
print('Corpus length:', len(text))
#new = text.split(" ")
#print(new)
# Out:
# Corpus length: 834860

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 278267
# Unique characters: 58
# Vectorization...

# %% [markdown]
# ### Building the network

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               95744
# _________________________________________________________________
# dense_1 (Dense)              (None, 58)                7482
# =================================================================
# Total params: 103,226
# Trainable params: 103,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ### Training language model and sampling

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 278267/278267 [==============================] - 180s 647us/step - loss: 1.8254
# --- Generating with seed: "great ridge. there seems to be a smoke or haze over there, l"
# ------ temperature: 0.2
# great ridge. there seems to be a smoke or haze over there, lith and the shade of the streak of the shade the moures of the right of the shade of the great were and the strange of the hard be the came the mouth and the streak the shade the shade the streak of the shade the streams and the shade the shade and the singing the shade the shade the strange of the great the dark of the streak to the streak the strange of the shade the mouth and there was the stre
# ------ temperature: 0.5
# ak the strange of the shade the mouth and there was the stree, the manches
# more and there the was
# them, there he are go the treeping not
# the streak the ores
# was stort he
# were him the dourntards and had the north them and the shade and at live a mind entle of the great
# plate and a fing him bears of the campen not bour and be preced as he had them.
#
# 'we sam, and seerruce of the
# light,
#
# there will see somethere them in the
# came
# of the ritherned him
# ------ temperature: 1.0
# e will see somethere them in the
# came
# of the ritherned him! if why gates, stall our isoot un!c'
#
#
#
#
# though behindesh wark. the dorning on i deeverless: shutter at rimged and slape, yest liverness eddenethor or deawins,
# ofronder of the stowey nafter of the jogeplemericing. in, the bet it wait, up surmunder of sit of
# the lawar, a theiress. will come paked
# chand, paurned ,
# fin oftone bucking ofter him. neethern, and is the greates heed mechain as me!'
# ------ temperature: 1.2
# fter him. neethern, and is the greates heed mechain as me!'
#
# 'noub-rower plaateringer retar. a fing oldand;
# 'i wishil gear world. it smumarkeded.
#
# if he man plape shope of pointes appivtotiosh.
#
# at we ised of wi afinters oot.
#
# go burety
# you had yet.'
#
# it afied the
# carrardardis gitemed greved emchirk aren's andir tormed.nfed, away of the tolking maruss, he
# shelled. get them. have up the are, i founder. yes indour there?'
#
# dmaduren,
# you boromir mo
# epoch 2
# Epoch 1/1
# 278267/278267 [==============================] - 174s 625us/step - loss: 1.5405
# --- Generating with seed: "ant and counsellor. when the plot is ripe it remains no long"
# ------ temperature: 0.2
# ant and counsellor. when the plot is ripe it remains no long the stream, and the horse with a dismone of the stream, and the hobbits was see the stream, and the stone of the
# stream, and the stream and the forest and a streams of the strang and
# the stream and the horn with the horse with a been been the
# streams the stream of the stream, and the other and the streams and the streams and the strang and stream the trees of the stream the strang of the strea
# ------ temperature: 0.5
# g and stream the trees of the stream the strang of the stream whunter the dird of the the round and with the stream bituse the horse
# that we come the white the
# stone stain before the high to be strong
# stranger of the some to his eyes and
# for it seemed the strowl and
# for under the mountains of the sirming but the stair as the stood to the sink the trees.
#
# 'i said and fell rest
# to the ent and the
# filling of the horse wood, i
# seemed to the
# companing
# ------ temperature: 1.0
#  the
# filling of the horse wood, i
# seemed to the
# companing to the
# edgen’s at now that tom he could citot roadered
# legolass, they falling time , sky a
# compon, himseld for wy
# been four slowly oin the discan this dark rive putless
# all at itherles, like nay rabbing hourd, sway at cause ready. 'bunboy lendly. the who ladd sam with she.'
#
# 'no get grey opence. we mise graat stifl came lake at it
# reached not make the streem becomes. mered on the migst
# me
# ------ temperature: 1.2
#
# reached not make the streem becomes. mered on the migst
# me,
# sam;
# him otherdof snow! for now -wn'n put itsengy again to bryingle. itny sudden the some going? fne came name into the stomy cry turn which lighe, my seaiesed; him twatry.
# say one was plainin night eyes. 'walking of the estee, there was one, dafled gone,
# did.’
#
# 'no! thill comeselm, and i as wind to nirbor? than very ofpir and tul alo-thf we beh
#
# it, backed, and at his light then the farr
# epoch 3
# Epoch 1/1
# 278267/278267 [==============================] - 174s 624us/step - loss: 1.4755
# --- Generating with seed: "at last he
# rose, and now his friends could see his face: it"
# ------ temperature: 0.2
# at last he
# rose, and now his friends could see his face: it was the wild the that he was the stand of the sun and the fire of the than the
# stard and the stream to the
# some and the stream to the
# the that he was the
# trees of the end and the watched to the
# trees of the fire they were the trees of the stone of the trees of the stand of the far
# that it was a which were the more to the stream to the trees of the stan and the stream of the
# trees of the st
# ------ temperature: 0.5
# the trees of the stan and the stream of the
# trees of the stones and
# the
# last
# with many the sun to the
# trees of the wall were best. we deep the same before the the more
# were
# that he cannot gollum. all the elvish back. he was a hills that still sam that shall be the smoke from the
# sonce. they were any to be strong the
# anceent and
# the last. 'he's
# dark to falling and speak of the water they has
#
#
#
#
#
#
#
#
# the
# agore the trees of the
# angress. now we s
# ------ temperature: 1.0
#  has
#
#
#
#
#
#
#
#
# the
# agore the trees of the
# angress. now we so from hil men, cill; and haspagold: it
# pass him.  tried some water, there toirly even wey of dishum hands 'ah.' endise, i will know the watch but odered my ness at kill,' said aragorn.
#
# eyes felt
# trues and towers, any popered topss of the even was to sheliness.
#
# 'not hearer, whiteress of a long angrel, and i as any
# of it! queety were, she doubened
# in agose a set
# they were seerling's halfs.
# ------ temperature: 1.2
# e, she doubened
# in agose a set
# they were seerling's halfs. but they ranci'
# was i had amazet pan free outwark hes?'
#
# you know no
# afted atowhen queston's angred corpowers-gollum!
#
# 'pery that welh.
#
# at that he make it, to'.' here watled to be moot hast wild uply mound for so poor they can!' then you wert frodo.
#
# enty permy lookive since you aip aisled weepingcal, helf in fisi!' said pippin undied, jomer turn out i -stirdy that there? who, they work bu
# epoch 4
# Epoch 1/1
# 278267/278267 [==============================] - 173s 623us/step - loss: 1.4427
# --- Generating with seed: "battle, even before you
# encircled your foes, maybe. can you"
# ------ temperature: 0.2
# battle, even before you
# encircled your foes, maybe. can you was a thin the mountains of the silence of the strange of the some of the some of the river of the some of the shadows of the silence of the hobbit stream the
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:3: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()
# stream the way of the sun and
# strength the stream was a shadows of the way of the river of the thing of the stream to the stream to the stream of the some of the silence of the some and stones the end and the mountains of the some of the s
# ------ temperature: 0.5
# me and stones the end and the mountains of the some of the spear of the rivered and walk to them. if it was
# the eastern had pask to the rock some coming and drawing away where let it and was far away forward the filldering of the grass and
# more of
# one of a live the hir worse was closes and a wizard that he may me the hobbit know him and the way of the hobbit mouth to the hobbit promised. 'he was a shadows with not shall of silence of
# this werss and the
# ------ temperature: 1.0
# s a shadows with not shall of silence of
# this werss and there hobbit to see in
# the riw horse? i have usonot that his greys in his
# fearonsed, unindard alroad mastered without has pass away the some dark laughed on passed to flaels round
#
# preat mile in it strange cold lords of
# veninusubg. set a gramterfall, before theme reath; say, when he was a mithers and in yeor devitr. so that so owen, and they little that. have threed to drunk of bost just upcarume
# ------ temperature: 1.2
# they little that. have threed to drunk of bost just upcarumegs oce. it di many fiercive over a deiranked. he har lesse't stead, and will firstening him yearaken to ward. 'you shall cost, drip. hooceted year
# hobbit of twide walked to frodo
# was help, knows wild not followed knowors kid hor righs hime'n in. then he halyshrows,' said gimli drivide down. the face from the of for ups, but gamlid he hode a legold meeged about a myrable was are. where there gand
# epoch 5
# Epoch 1/1
# 278267/278267 [==============================] - 173s 623us/step - loss: 1.4207
# --- Generating with seed: "of saruman is washed away. then isen can
# run clean again." "
# ------ temperature: 0.2
# of saruman is washed away. then isen can
# run clean again."
#
# 'the enemy they were the
# water of the enemy the end. the enemy is the wind in the stream of the end.
#
# 'the sunlent was the strange was the
# bank of the trees was
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# and the
# water of the sunless was a
# morning silent of the
# stream of the
# back and the stream the
# through the
# bank of the
# rolled and the will
# stringed and the end.
#
# 'the straight
# ------ temperature: 0.5
#
# rolled and the will
# stringed and the end.
#
# 'the straight say that i have his
#
# straight and like a morning to mave in the hourself to his, and the wind of far there i will me not that it was a stone them there was no the fordered began him and the tree. the elvish in friends. but no be was a blank. and they had the
# window and stooped to the forest and
# his
# broken and
# the staff for
# the will see the horron of the stream storm. the brief air me and th
# ------ temperature: 1.0
#  see the horron of the stream storm. the brief air me and the bright and low of the athers of
# isengard more wound. then it make in suddenly.'' enemy
# than ents of the wild to meirking
# to the glipta. cermors leave his been and never hunce begiflil iclees, the eiven oed of a leng!' he said,
#
# 'and you fires to
# seen
# frog the greeth of nalud off and rother been. but gandalf round
# fning of the
# fururm or onewhre’s than.' shilest of of in the holloms. in yo
# ------ temperature: 1.2
# rurm or onewhre’s than.' shilest of of in the holloms. in your sablae wind? robanlis youss laughed air
# me? be parting into his cold; right; the driunt to bil, are unspet very your face poces,fand: he dremped to the galtomatkness thindering again,' said up out into the lill-water, ladg of a sarent than samel driel runge gone.' the in only safe each turned sttfrath othen,' he
# asked with gollum doimsurects, depavedling.'
#
# 'doubt,' saids -frester upon the r
# epoch 6
# Epoch 1/1
# 278267/278267 [==============================] - 173s 623us/step - loss: 1.4056
# --- Generating with seed: "s. beside him merry lay, white-faced, with a dirty rag bound"
# ------ temperature: 0.2
# s. beside him merry lay, white-faced, with a dirty rag bound the stairs of the stairs of the stairs of the starp-stream.
#
# and they were the starp-sword and a shadow and the stairs of the battle of the stairs and the shadow of the stairs and the
# wild of the great mound and
# stream.
#
# the long was strange stream they were to the stones and again the great was strength and the
# stand and they were began to the stones with a shadow of the stairs were a shall
# ------ temperature: 0.5
# began to the stones with a shadow of the stairs were a shallows of the stairs there were
# hands of the way of the grey silent of the sun on the wild and the stones the hand. when if they tell the ents of saruman had been and the thought.
#
# 'you deeper to the read for the wars may be the arms of the stones again and stain. they had come already and diken and arming before the bourns of the
# trees
# with stained with a master with a brand of the forest stood
# ------ temperature: 1.0
# with stained with a master with a brand of the forest stood when helm took up there was a treek. he was above call up and line of
# the hobbits sprang upy, if it had tume
# abour his fording mountains: they feary and the wetching out from the long
# paces was
# now. i cannot be d
# forzaw to didn't terry he began ter his eyes hood or mounhold. 'indeen no watchy of my feet, but after a listen and hisieven a house nearlion. then they do not aright to his eyes and
# ------ temperature: 1.2
# en a house nearlion. then they do not aright to his eyes and think? him, very hoac-esk. one scanned wish is feal ond back. 'they trueds understan the others.
# are awake out of marwenings, and ane inees flavelue bed hask hobbit lift you't wing that and of ' not all blamits toinshed fous listoned them, and tere
# forest again, and stood now, 'na'lying passed us.'
#
# 'lost yet biin; my rectimilight.'
#
# without beto yes,
# he dwast, wearing time
# his iswas.’
#
# 'n
# epoch 7
# Epoch 1/1
# 278267/278267 [==============================] - 173s 623us/step - loss: 1.3963
# --- Generating with seed: "ed feet do not falter.'
#
# 'as you will,' said gandalf. 'arag"
# ------ temperature: 0.2
# ed feet do not falter.'
#
# 'as you will,' said gandalf. 'aragorn was a long
# stones and the
# way and the
# great bright of the
# breath of the
# ways of the sun
# was a
# stones and the sun off and the shadows of the
# stream and the
# stream that has the
# shadows of the stafted of the start of the
# stafes of the
# way of the
# stafted and the stream and the
# shadows of the dark
# strange that he was a
# stafted and the
# cloud of the stars of the stream. 'i will
# see
# ------ temperature: 0.5
# ted and the
# cloud of the stars of the stream. 'i will
# see them for a moment and the seemed of the trees with the stones of the road, and the
# slopes of the clour that were all and the turred, some all war
# the way off and a shadow of their shades of the read of the hobbits and to the sun
# sword, and they shall make a grey sound off a trees and save the face of the great querely with and with fires and heart hobbits to be made a mord of the
#
#
#
#
# well of t
# ------ temperature: 1.0
# es and heart hobbits to be made a mord of the
#
#
#
#
# well of the stormsleazturd and his abrous song time.' 'wear
# rep it was good in his platen kneet, and our horch.
#
# rumbes. morgul behind the mountay 'than ear them that rest under the gates,
# sam cry. a blose hig shadow, upon light connegore three loudself; and i wish huttlesly while.' did not she was,' said gandalf. 'yeul pourous nacled gain downderly your eyes to land in the pleash in them -fadcing great
# ------ temperature: 1.2
# derly your eyes to land in the pleash in them -fadcing great getters teadhes. the ladd garch's 'waless forle! when once under margike. yay i was between one course, bending lived
# dome, stout have growe.
#
# to is though the end's a know geclo, but what longed behied, give
# some rour halfall; we is tame,
# we must himp and tell,' has hoges! glacc you have right cay fading up, show grunts, treebe joswed and with ret falling forward have hadled. cele. made him
# epoch 8
# Epoch 1/1
# 278267/278267 [==============================] - 174s 624us/step - loss: 1.3855
# --- Generating with seed: "ouble
# coming to us, mark my words!'
#
# 'i mark them,' said a"
# ------ temperature: 0.2
# ouble
# coming to us, mark my words!'
# 'i mark them,' said aragorn. 'but they were and the stones of the stones of the
# stones of the stream they were and the
# stones of the stones of the stream of the stream of the
# long
# stream and the stream of the
# trees of the mountains of the
# stream of the stones of the great black stones and the trees, and the trees of the end of the stream of the
# stones of the stones of the
# way of the trees, and the way of the
#
# ------ temperature: 0.5
# of the stones of the
# way of the trees, and the way of the
# shadows of the briesten of the feet and he took to the enemy.
#
# 'i said aragorn
# he took
# them. the north was some thought he said them, and the storm in the mouth of the
# long of the woods of the guards of the
# watchers and pitping for they were been and for a long stood their horses, and they were spears and
# their eyes to
# his hiss, and sam had a
# stair,' said gimli. 'i do not died at like a la
# ------ temperature: 1.0
# d sam had a
# stair,' said gimli. 'i do not died at like a last alive the end of the hills of dough. they heard an glimmled wurling
# back and to weadowty also
# nothing the shadows of
# order, and we may pite later for any legolas; and we can. there was are anks
# was seeming acried and knew their bears guare
# about the tunnort,
# so osting his had an true;' he
# enoughed him my ise,' said
# bright other through the cliff's flissereas, one out-horses. with the
# b
# ------ temperature: 1.2
#  through the cliff's flissereas, one out-horses. with the
# boob: or then did not
# knone?' said ! and he stugiet, if they gave him: i seven samnrumstness. turn the yeelt in the cliff. '
#
# 'but why now aragorn.' they found. dud
# he cast they knew the vrives unthand.'
#
# 'ievquar the house,' said frodo. for as a lide would to have fy olthen? you mading his mere, leagues understand lead. the bone ofe store he said, when if roushed 'yonel. herd left met you fear
# epoch 9
# Epoch 1/1
# 278267/278267 [==============================] - 174s 626us/step - loss: 1.3779
# --- Generating with seed: "n swiftly down to where the river
# spread in stony shoals be"
# ------ temperature: 0.2
# n swiftly down to where the river
# spread in stony shoals between the sunlight. the strokes of the streams of the
# strive and the sun
# stood and the brows of the
# stream. i shall not the
# come the stones, and they were and the
# countress.
#
# 'well, i shall have the stair the ford of the stream. the trouble they were forget the brows of the stream. it was the strength and and strenger they were the strength and
# stood the sun had been
# stones and
# the words
# ------ temperature: 0.5
# strength and
# stood the sun had been
# stones and
# the words of the
# end, as
# he of the stending and
# all the stream the time. i have forder the
# steps of
# the hobbits stair. they were the things here that he may he feel their sky. the too now nor of the sound of the horses, and seemed that the hobbits they down the stair, with down on the rothers him of his chance. sprang
# strip and screech and it of the hours.
#
# if i said it with me, but they was will the
# ------ temperature: 1.0
#  of the hours.
#
# if i said it with me, but they was will the trees. 'have seen, and sife had in my deid on of the hobbits happen yourly. 'to his bank,' he said course deep,
# and with that if sam ents.'
#
# gandalf thound morning,
# who grassed to or till;
# and they gooded to rearsgain. there of the bean valley. 'we ligh, or such to feit the asope he flinging afreen we had no cause perwains of light. the roald wor as such down the robbt. apprope, or hegirk upo
# ------ temperature: 1.2
# the roald wor as such down the robbt. apprope, or hegirk upon their
#
# inip,
# or
# of
# nonet, and their great with through yeeliel
# crept peagrtayed aware plent.
# even hesecky, therseling on
#
# is no ose. lighs stood the vanible all appeared they ores that their slopes, thed.
#
# 'that south the hall of our rodents,
# herounce!'
#
# here
# straice talder of cleft forth: thesh was thok-was that as he sloming eptive them pllalol, and althe, just
# pasken fomert, d lea
# epoch 10
# Epoch 1/1
# 278267/278267 [==============================] - 174s 625us/step - loss: 1.3805
# --- Generating with seed: "ething of him? '
#
# 'it does,' said frodo. 'yet always he tre"
# ------ temperature: 0.2
# ething of him? '
#
# 'it does,' said frodo. 'yet always he treebeard and some to see the shadows of the
# stream.
#
# 'i do not see the shadows of the shadows of the
# lints of the eneming and strength and a
# strength and sleep of the stream of the hobbits and
# strong of the hobbits of the mountains of the
# stream and strong the stream of the shadows of the
# strangel and come to the
# strange that he had all the though the wings of the stream of the eneming and s
# ------ temperature: 0.5
#  all the though the wings of the stream of the eneming and sleep, leave some old forth the
# stream and a while shadows of the eneming rider of his heads of their top. the land the starly went by that he was back with the staff. and came the shadows of their chance.
#
# 'i will make his ride, that shall
# and the hiss of the grey seemed to sent far and the asher
# which he wars in the
# horse and
# preced to the
# feet drawn black see and streng of his heads of th
# ------ temperature: 1.0
# d to the
# feet drawn black see and streng of his heads of their mountains with his rarching hissed oversewn
# roof. he has going
# so since, you shouth only and had that,
# shran,' said crung back and say,
# ne
# leavesy ais hais. side swimloted. nice hobbits treep, spad in the sincell made wend, by gollum was halted theashs sat bright with string darkering and the small of some blades. most are speak of the broots and his wrad, as pitriedine with we's alall
# w
# ------ temperature: 1.2
# of the broots and his wrad, as pitriedine with we's alall
# wicc thlif and you fining hunter's svery years had come you, ablulds on our strang was meming with leg to elsk. they! a loof'tfuly, ’ sillued far relads,’ said for you. heoot,' said thjoden, rebion. hlust, see it, as anigh what-bry!' a cocc'th, after the latven is evervossspoils of righ? salumss,' cain, i word. not i doe. servereth moon are glind his
# preci3tffeled, measens.'
#
# until we would leave
# epoch 11
# Epoch 1/1
# 278267/278267 [==============================] - 173s 623us/step - loss: 1.3957
# --- Generating with seed: "et steps, and so
# came to a small flat landing cut in the st"
# ------ temperature: 0.2
# et steps, and so
# came to a small flat landing cut in the stream.
#
# 'the great stone was the
# strength of the
# strangers of the way of the standing of the mountains of the
# sun was
# before the strength of the road
# and the mountains of the
# light of the
# commors in the trees
# of the
# strength of the
# strength of 299ming of the
# commors of the stands of the way the course of the
# stones 6*9bust to the
# ents and strange beneatth and beast to the
# sword of th
# ------ temperature: 0.5
# the
# ents and strange beneatth and beast to the
# sword of the might and at was
# three that had that the stars the
# stirring was and last to be hard at the
# counsel out into the tale called stair.
#
# the east for mordor was and deep in the bair7ught of the horse of the sun
# the eastern of the dark and in the trees.
#
# 'i she could far and the
# great man there they had been benom isengard, and the ents
# bowing the man and
# back with black than rohan, and may b
# ------ temperature: 1.0
# s
# bowing the man and
# back with black than rohan, and may betteres of sam is elvish memotaiated the curunstes: it ise, but us forth
# bright; that was human,
# masterly land, he seen a elves, even slowing to oot, and and green seemelm, sound was what he souked. and right could meands everiry:
# the way of
# his hand unlikes.
# after they you may criver.
#
# the forder of back at 6lorg in the open  grinht?' he said. 'but i think, i entard
# very apin,' and before
# ------ temperature: 1.2
# t?' he said. 'but i think, i entard
# very apin,' and before shutchiey smj)e, and ine wine gaken your gat thromolfully syetemev. i vermaring to the way. it rain, my; quite one yet as he sone pass when my burts cartainly, they
# say before bean again. he don't seen. in a hohm. then bright rane's. short our herms may now began toover. as the basry they came — across these turned gandalf staching, with done! avemurly,
# inhelty shoked walk knowed for 7val wone w
# epoch 12
# Epoch 1/1
# 278267/278267 [==============================] - 173s 623us/step - loss: 1.4332
# --- Generating with seed: " more.’
#
# 'and that's enough! ' said sam. 'ugh! how i do hat"
# ------ temperature: 0.2
#  more.’
#
# 'and that's enough! ' said sam. 'ugh! how i do hatering the fair stood and the company of the storm of the stream of the stairs of the storm2 of the great
#
#
#
#
# stones of the stream of the stream of the staring of the staring of the road
# stones of the west of the great last stream and stones and the stream and the road hand the road hand. they were a stream and the broad of the storm.
#
# 'there was a deep stones of the stream of the storm of the l
# ------ temperature: 0.5
# 'there was a deep stones of the stream of the storm of the lord of the great pass of the
# lord and
# stairs of the stream of the dark road
# and
# the men of the deep from the bood the old of the great way and he could do by the soft who increaking
# and her hiss.
#
# 'we hav9, did not do not4t?'
#
# 'let us it for the tround now with me hold of the broad the side. he was leaves and
# frodo began in the bowled frum the
# banks.
#
# 'but they were the way there of the
# ------ temperature: 1.0
# wled frum the
# banks.
#
# 'but they were the way there of the wingas from it.'
#
# he two wind! ' grown their drimbe bent and your hand and under it, and so
# hougt: i must found to hear the inch-brooching from land, and some
#
#
#
#
# el“mined arm, as you i
# wil2 8twounds,' said frodo. 'you find while my battle,' he said, 'eppake, red another preiled out
# swones.
#
# the dived came, on itsurfreln it went mordor's fador of some too chouddnest, had shall be
# no drop at
# ------ temperature: 1.2
# dor's fador of some too chouddnest, had shall be
# no drop at a merry, blarchin in fi3m) and there were tood toblul down, and masters
# 9ldveringily. eating. doin sam drawce lit helping. then pippin -mome journey thin thought of peace8-way, all the news of either is shall eagher reach stal at mordor ray guts, if 'hem, mirmory need not your tood buined goll hes besare cust nom broke began in our time aboved, not food, of it, he moving into pooln-tofound famin
# epoch 13
# Epoch 1/1
# 278267/278267 [==============================] - 174s 624us/step - loss: 1.4985
# --- Generating with seed: "ne
# new-awakened. i would now that you had come before, gand"
# ------ temperature: 0.2
# ne
# new-awakened. i would now that you had come before, gandalf said the hobbits of
# shadow of the way )ness). 'the smelly of the horse was strong and the dark
# stream of the stream.
#
# the wing was for the strangers and strong
# the way on the
# stream.
#
# 'not for the wing is the thing of the
# strong of
# the wing of the stream of the night of the
# strong of the strangers of the
# strong
# strong
# of the search of the
# through
# the stream.
#
# 'i have have
# to th
# ------ temperature: 0.5
# he search of the
# through
# the stream.
#
# 'i have have
# to the ground of the hobbits the hobbits was the wall, and south of the silent long thought and with the
# mountains of the short words of some smelling day, and the in saruman has the enemy, the chance and slipped
# the
# and to, i spoke the old and preciou).
#
# 'he too
# isengard that he felt
# to
#
#
#
#
# the
# fair, and he was stone, then for a while the too of the deep).
#
# the will was the
# fingers in t)ver,
# ------ temperature: 1.0
#  the too of the deep).
#
# the will was the
# fingers in t)ver, that an. he is enemy into him. not hopalved
# us his ming, peds the
# finglice inteed it seallw at the men in the tracklen totht o6ab's into his trupl!'
#
# 'hut legolas long,' sa)d saruman will be here.'
#
# 'no, unlasing us out of -wor' live the side, and on their potter has efted dalf. let on the maral us no riders, a due needed not. but when they had going themun; and she
# legolas road by it. all w
# ------ temperature: 1.2
# en they had going themun; and she
# legolas road by it. all warmitible i would not me it. where he wis
# a bunur.
#
# 'a like 4rwcame that not gnod. he knew metry morning. i cannot swe mr. *grow, up
# of ispnew; for it your makre? for 2nly!'
#
# gollum to indeed, now
# impy. it you fee,, i have helps.
# they doest up that gens following too, drawy aid's
# ride not; and but i can he' has you that makestay at the mrial
# days, as he should turn you tlit the dupe, se, w
# epoch 14
# Epoch 1/1
# 278267/278267 [==============================] - 174s 625us/step - loss: 1.5371
# --- Generating with seed: "ver in cold blood, or more unwise.
#
# 'no, no! sam, you old a"
# ------ temperature: 0.2
# ver in cold blood, or more unwise.
#
# 'no, no! sam, you old as he st)by t)vered and strea) the stream.
#
# the sun had seemed to the stream.
#
# 'there was a hobbits and the road of the stream.
#
# 'then the)-ranger was the long sturd stream of the trees of the stream.
#
# the sun was
# stridered the hobbits of the
# stream.
#
# 'then he was a while)
# and the
# stone of the stone of the stream.
#
# 'there i) the wing was not the hobbits and the stafe of the )glit and the s
# ------ temperature: 0.5
# ing was not the hobbits and the stafe of the )glit and the stream, and the end of the more
#
# is the swords in the tower from the
# walls.
#
# 'i were now of the
# eyes were him on the stream.
#
# 'not the hobbits may heard the small company and decion and sam in the east of the water hob)ves,)’
#
# 'straight). 'we are the dark some answered again, and at fangorn
# and the stream; and the enemies were once the
# moon and still faces threw
# streaming from the
# stream
# ------ temperature: 1.0
# the
# moon and still faces threw
# streaming from the
# stream of the name of) in w)n2weardar, there
# ever
# see to joings frodo and the lighter the stunr of the great spreams 2 like evening topp; the time and seamed rohan to the start. no, nearer
# the
# end. then the mark was the sunlight, and the mendis back towards fangorn, little you in
# )n. sam dud. then a 'ig. )g! why
# besided it )bbly his anfrillow vants. cold runngard there, but the
# hands tapered,7) wo
# ------ temperature: 1.2
# low vants. cold runngard there, but the
# hands tapered,7) would.  will help to seen myself; and we prongliuge, as yow
# endures
# will do or ton’t fishtice he stil“)red him. ! ' the furtherthelf bow. gollum )ebass),
# legolas or like
# an well 6fust
# aed iredtered upip! for it seemed him
# balbeached in the flost fear rase hard friend to the eyes long wat5s? helcce,' said down, sam, i co)! their revectperingar. up the ho*7, afiel, in the top, theremwelleising).
# epoch 15
# Epoch 1/1
# 278267/278267 [==============================] - 174s 625us/step - loss: 1.7102
# --- Generating with seed: "ell, they say.’
#
# 'they would.’ grunted gorbag. 'we'll see. "
# ------ temperature: 0.2
# ell, they say.’
#
# 'they would.’ grunted gorbag. 'we'll see. they were
# and the stream.
#
# 'and then i should say. the stream of the way and the stream and stream )ned to the stream.
#
# 'wellen i saw the stands of the wind was not the stream.
#
# 'then i say, i shall make the stream. the stream was seemed to the stream.
#
# 'i do not seemed to me and sam that the world and the stream and the stream. 'i saw the stream of the road and strong sam in the watchers of
# ------ temperature: 0.5
# aw the stream of the road and strong sam in the watchers of the stream. so he saw the way them in the wind.
# )t).
#
# 'i say, to the guard might be seen they laughed. 'i says that the ores now are
# still
# smjagol, and the trees was the horse, and the
# answer).
#
# 'and they had a stranger and seemed to a more strong not the other great bright and the shadows of the way.
#
# 'what's how i will go a), and they came and the arch and all in the thing )eld. crown
# or
# ------ temperature: 1.0
#  they came and the arch and all in the thing )eld. crown
# or warly;
#
# i dread ugl)d like right; and a look -sna) away about rerrain from the tree; but it wonder without
# he is
#
# t)near. bie de)y the names to), and b)tness): the
# toweded in the long
# sun's named on their lord to
# lifted. force
# thought is night. after the deay d nomteres ))ness: his tree! is they w)ward what anothers's uncelping far
# off. i truatled him precious on the fords, at )glit.'
#
# h
# ------ temperature: 1.2
# r
# off. i truatled him precious on the fords, at )glit.'
#
# her ore as the edge. out neverf, . not?', wonf a smell flink.  picked changed. the damter saruman was softly bodian)o, 'fover), an)?' drawny or sween of a)d from c)))! fimy lall, i )ds!' said gollum. 'post in rump nazey forsolk. bunb uce.'
#
# in the feet )in2)-and wless, theml tcourse ei).).
#
# a chiefing!' said not folpotsing. he was brools with after the). there goll on time. but eithere eaot. we e
# epoch 16
# Epoch 1/1
# 278267/278267 [==============================] - 174s 626us/step - loss: 2.1000
# --- Generating with seed: "s the long valley came,
# falling steeply in an ever-widening"
# ------ temperature: 0.2
# s the long valley came,
# falling steeply in an ever-widening of the). the arms) the m), an). 'well, the mountain).
#
# 'wel).
#
# 'well, well, the sun had stood the road).
#
# 'the world was the shadow of the sun had sto)ders of the cou)d and stones and the brok)-borders of the shadow )n.
#
# t)near was th)ness, and). )glin)).
#
# 'we)ce is the broken the staring was a
#
#
#
#
# bunned
# and the sun )nkes.
#
# ')n)d the forest was the c)))))).
#
# 'well, i say the rider of th
# ------ temperature: 0.5
# d the forest was the c)))))).
#
# 'well, i say the rider of the hills story and the forest of the reek of the paramis) and if it seemed to the riders a)d the sword), and the call of the tower of the
#
#
#
#
# black the dark spring and the )nk
# )ning an), bu)ness a))))))d )g?
#
# '
#
# 'but i have been not his stranger was down the ground. the ))). the t)vere is)). the broken was had)! i am he))), and began that the stand of )gu)n)ead his fashion before the black goom
# ------ temperature: 1.0
# hat the stand of )gu)n)ead his fashion before the black goomh his words that
# worse in )gve)! even )in was )ca). )war))d i
# said. 'mat latert it? i have no webout truin) and her short for a windst. they are,' said ara))); that is any  voi)o)t its brou)nos, bitter? '
#
# 'white i onip.
#
# or find trees have be)-)nk hung)! no'l been)) i set )n the)-fully, his
# shather smallers falls)). 'my that i say dos it;) ores )g's)v)ne). all no nou)t kindly etrall to the h
# ------ temperature: 1.2
# os it;) ores )g's)v)ne). all no nou)t kindly etrall to the hope hunter wondery,' said so nam); the )ge;
# voice would)! o)cet beaster)?
#
# creard dentter, small banks y)s)ed )nunk, bu)n h)ablent )g))), among )gvis, unyeln,' knhe in hilleling allo'td), troth plags,)namhornert. their staliitifl, eftl)nesss), and if). and
# yet, )wp, of their rank waes
# soun), approchpaes of gates to
# tear. fo)eading led. the chol)?  for)de))ed leg)ucern
# given it, or the s)ze l
# epoch 17
# Epoch 1/1
# 278267/278267 [==============================] - 174s 626us/step - loss: 2.1524
# --- Generating with seed: "y who has done me so much wrong.
# jomer
#
# shall come with me"
# ------ temperature: 0.2
# y who has done me so much wrong.
# jomer
#
# shall come with me the
# strength of the s)wpin) a)d)))e
#
#
# the thou)) the thing and stones and), and the water was t)ver may should
# stronger the )ning
# and strength and the wall of the ))wards of) the hobbits were stairing the
# stream and), and the thing was) th)ckes of the window they were sheld the stream of the
# stream) the), and the storm were a
# stair of the str)ing of the water and strong and strenger that th
# ------ temperature: 0.5
#  of the str)ing of the water and strong and strenger that the)-rid the rider) the precious, and )wbly,
# and
# the sun in the other arms of the tre)-)und.
#
# 'we)n the world is some thing).
#
# 'the m)? ' he said. 'the black shall shall dou) the reeked and see the cliff cliff)ed) t)ver from them and needed
# the
# streamen of the watches of the
# thi). and they were stills the hobbit). when
# t)ness). 'but something may from his as
# i)d
# )cnes, and a hours the )cke
# ------ temperature: 1.0
#  something may from his as
# i)d
# )cnes, and a hours the )cked )ey. cold came )duin, in the this oreds of
# t)ver at my).
#
# 'he go thi). do that broken
# smriok draw). this made a black, we shall
# me. the w)ver among rankly me doh! gream,ve), )t'slead
# perily something som), maybe evilels-scrank indeed.
#
# so as fear mor). frodo c)ver whre dark for over gongon like in
# to our thall, resting his tree; but the)? let)
# a) to give to pr)e: i pushidion, had because
# ------ temperature: 1.2
# but the)? let)
# a) to give to pr)e: i pushidion, had because )g-his own
# folk road o) our, slupi, east, i) amazed !)way thusly h)xwcood
# now!'
#
# ') yes. but thought almost is them, and in this, first i aly boli! i)-unbu)e
# it!’ said
#
#
#
# his ree.'
#
# 'rid thing, hmeed, my hoad your,' said aezquau)erming pition.
# we may frieins; unheard, )azoonl, setr us saruman youd )nce quietly;
#
# it wonderums, ydl))ed how slowly lys or )on!'
#
# his bamed ever a)d.' stay cris
# epoch 18
# Epoch 1/1
# 278267/278267 [==============================] - 175s 628us/step - loss: 1.8383
# --- Generating with seed: ". long slopes they climbed, dark, hard-edged
# against the sk"
# ------ temperature: 0.2
# . long slopes they climbed, dark, hard-edged
# against the sky c)veres) and the )nkes were
# companions he saw that he saw that was a thing the
# mountai))). the), and the shadow stood and the stream and str)ing and strong was a stream
# and the stream and
# strange
# stood and str)ing the riders and the stream
# were the deep and strong and strange
# and the stream.
#
# 'you say, the stream were the riders and the stream.
#
# 'we can) he say and the wind is the with
# ------ temperature: 0.5
#  and the stream.
#
# 'we can) he say and the wind is the with the thing in the silent strange stood. the ents sprang the deep of the athers.
#
# 'and smjagol should be made beside a little) and now and
# the with the wa)n)e’s
# and the hobbits were stream.
#
# he and him and as the grey stride.). ')nward
# the strange
# who we will be
# the stranger in the endless had been the ready the clouds and were drink. the trees of the road and home we seems).
#
# 'i shall not l
# ------ temperature: 1.0
# . the trees of the road and home we seems).
#
# 'i shall not led
# ly in bohisn that for his), and darken! and did pitched the last r))cen strange hairs and passed. out on ore, h)bf, that
# sat still seemed thet, earest you
# a). and they were over the time a land of the shadown of the holes as at runed). the defers they ca)vered, if arasost is what yet by the winder
# would blake what
# prinely sam ill and the
# lord. we have one )nkes)ness back himself, whiles h
# ------ temperature: 1.2
# and the
# lord. we have one )nkes)ness back himself, whiles halfed
# a c)band, never unwet well may tb)birding itsooping care known, some or,' he ferst. which frodo had into i)nk.'
#
# a hobbits ’)'nam!' was )epholi)n ore, and thought than gimly li) csurcliig iad to restily. a
# sick whomw) perhaps: achien waa), folder will yousnet me
# don; and )nanted holdert was them ony inward. bal) the north
# hullenstlith we boneling
# it in thickss!' he cast
# go )e’d mads a
# epoch 19
# Epoch 1/1
# 278267/278267 [==============================] - 175s 628us/step - loss: 2.1565
# --- Generating with seed: "he cursed horsebreeders will hear of us by morning.
# now we'"
# ------ temperature: 0.2
# he cursed horsebreeders will hear of us by morning.
# now we'ld be not )nked). 'i will not be the
# st)nked and fire
# fear an), and the storing head and)unk the
# stream and the
# stream in the r)ones of the
# earth was harse a few stone and
# came and )gked) the companions of the
# earth was beaut
# lard and
#
#
#
#
# come of), ))e was) it and the
# stone of) the ents of the s))))ean.
#
#
#
#
#
#
#
#
#
#
# 'the
# stream we)ck!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the ent was a
# large and the
# stream
# ------ temperature: 0.5
# e)ck!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the ent was a
# large and the
# stream if)ce and with the compa)neas: the
# walls; and i want in the
# gate the
# stre)ar))ees, and he came up and the plant and trees, and he would not seen an).
#
# 'we shall say, he will be the right). ')n!' said aragorns. 'i say you
# place make i)n't whirst to the wind the fork and countor), and any hear was a)dd good smjagol, and they shall)) he lears the breath and
# compan) of ores and sle)tbess, and th
# ------ temperature: 1.0
#  lears the breath and
# compan) of ores and sle)tbess, and the
# find )gw) unlerged ))). 'we fountry. 'come th)izad itum. 'to iseliming
# us as it safe yo))ead awr)))eat lost tore of end with anoth: our by the
# sit it. 'do, it seemed step upon the dark
# )cts )crt.
#
# 'stfurus, you
# satseen i. gollum
# much foundror ale men. 'we are us and), with himing it had ansked))ed
# on the rang.
#
#
#
#
# allows it drung. a long
# stranged path are formmalishoness-fare)ned in th
# ------ temperature: 1.2
# ng. a long
# stranged path are formmalishoness-fare)ned in the cores) by  cauld thppe and low edresh)), i cuset off. he )l?’
#
# and one)ce
#
#
# ), one scorors, may clay. fom t)nint was a whistzed came whf wa)n accors of
# . the red))wpy has red upof without thst from the )creat; corcked hiding and slopot v)nke. ))l!' are no) old ord
# green t)ved; even they cu)ve toy frofting, because of a thinurilils the crike s)ounith, no) the)er
# froness tim intoses with ten
# epoch 20
# Epoch 1/1
# 278267/278267 [==============================] - 174s 625us/step - loss: 2.8593
# --- Generating with seed: "he wolves ceased their
# howling and slunk away. fear fell on"
# ------ temperature: 0.2
# he wolves ceased their
# howling and slunk away. fear fell one wa)ned the way t)veri)))ung, and and the
# shadow was
# th)ck and the
# stone and the
# stranger
# was and t)ve) the tower of the story )gwing of the
# earth.
#
# 'i would have the )gre?)' said t)wvfor and )nke.
#
# 'i shall be t))ned the
# mountain
# of the
# sto)d the trees of the
# company of the stra)st the ))wards and)eam. and the )greman)))de the)-rean of the
# stranger was the
# stranger was and the
# com
# ------ temperature: 0.5
# he)-rean of the
# stranger was the
# stranger was and the
# company. he )gked.
#
# 'yes, i wandet the work that was a str)))ned is with his mist to me the earth; a)d th)s the ores
# will
# come on the horses )gness. he had been room the )gremat wha))).
# )gness o)ned heart is and)un, and t))end!' answered frodo. 'i am si)n the)-rea the moot their
# staring
# this close). the south war had
# not )nke))eadings of the land himse), or he f)))wards
# )e’s s)ubbins. the tur
# ------ temperature: 1.0
#  of the land himse), or he f)))wards
# )e’s s)ubbins. the turr) was a distaff. in )wzard his stone
# the ol))eakings of him.
#
# those may age,
# doors saruman) he hads).
#
# they ma)veled
# recl)oken. so there))cne us?’ said megay. unty
# the faced; but it). lord). a
# words called of
# the moun made i saruman;)'s very g)nt just a)obbit, and )rpes) it). 'but his lamp that the wearter trembi)))ear climfling. then ))fol fair is l)gcting
# course. the hill sto)cke)ed in
# ------ temperature: 1.2
#  then ))fol fair is l)gcting
# course. the hill sto)cke)ed in mordor o)no.
#
# pippin?) hask))), 'veruls! hy goi)ne swept you), )cl). the windor saves this. we saw let us)urf. them th)ck in it.'
#
# 'do w)very pading then h s from of thromd goidets of my thing it kning like eve), our old). )gked?)n at)ck he )uns to the awh strid), for the )inb)waddwes hardg. you o a, and h)-igh about loobt t)veriin,
# and its key commor)-
#
#
#
#
# chiofer harg))))de))))ed hills-will,
# epoch 21
# Epoch 1/1
# 278267/278267 [==============================] - 174s 624us/step - loss: 3.1300
# --- Generating with seed: "the point of exhaustion. he said
# nothing, indeed he hardly "
# ------ temperature: 0.2
# the point of exhaustion. he said
# nothing, indeed he hardly and t)ny a)n th))nead). the sun h)b))wards of the sun the shadows of the stone.
#
# )gning the sun had be)ned th)furring of )gne). the s))wable of the )gness were his
# horse of the )gness to the
# ston) an)s of the
# shadows of).).) the)-in the sun wa) )gness )gwing an)).) the sun)ver)-
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gollum that he was because the shadows of the sun had hea) an)).). )gwing w)ver).) and the land)ur
# ------ temperature: 0.5
#  of the sun had hea) an)).). )gwing w)ver).) and the land)urn), )gring come on the agold strong of the mountains )gwing forward to )), a)dd the).) the r)ive))e), an)), and bor)) the)-
#
#
#
#
#
#
#
#
# will )gned to one there
# was the
# great ))ned and heard on)))ed up.
#
# th)b)w in the
# the dead hand, and shadows of t)v’t you): t)wite the sl)und)ver of the elvish of th)fur), and the)-ready)urk of the
# still s)x;) an)s ther)-they had come all the fork hi)).)’t wa) the
# ------ temperature: 1.0
# s)x;) an)s ther)-they had come all the fork hi)).)’t wa) the once at once his)eath lau))ons )ny and )gself, and we more t)ved..' )g-help, wi)cn, see) acame many treebtive wate )wblithed loging, and between the a)wvegivi)g)waw)) from the )))ness in)orpdotce, )r)d knowed vidiek! anconhing th)fborshere turned )tfy)). all even )gfule it and)e))un!me dmur)), )ow the darknessurair was breen alk all a lands goings to mor)ment
# his pactering, and)curn s)uce). th)b
# ------ temperature: 1.2
# nds goings to mor)ment
# his pactering, and)curn s)uce). th)bftor))). 'go)e’)? and gimle we)ce maddeping), afte)ned seve). we left no good,' asked frodo. b)glehay. dwell had and courteay out
# )nr))nes your foo). not )ozin)).) a)ff suddenl))way )g?) ore is clifds). bu)n sma) we)ging yourst)n.), ’if,' said gim)u, mus). the )bzing voice wa))n, b)wleps: fair
# is owned with your woods, )gnait )fback on with)! so turnged ag)), an)t)'s )gris)).
#
# 'i
# will )d), )br
# epoch 22
# Epoch 1/1
# 278267/278267 [==============================] - 174s 624us/step - loss: 3.4156
# --- Generating with seed: "the
# uplands.
#
# at the foot of the walled hill the way ran u"
# ------ temperature: 0.2
# the
# uplands.
#
# at the foot of the walled hill the way ran u)gnet o)e’s stream.) the)-
#
# ))e)e’s). 'i do not to see the stream the
# stream of the stream of the
# strea)-forest a)s
# steps o)e’s stream ))w)ved.
#
# 'i ))e)e’s
# still the stream and the wall of the stream of the
# streams o)e’s )gwards of the
# streams ))w)ves.
#
# 'th)),) i say is the stream
# the ))w)ved
# and bear the
# streams of the
# strea)-broke the
# stream of th)fbl)-for)ead the
# str))f)e’s horn o
# ------ temperature: 0.5
# -broke the
# stream of th)fbl)-for)ead the
# str))f)e’s horn of)-)e’t)-
#
#
#
#
# endin))eath of the strea)-strangers of the stream.
#
# 'the trees of the p))e)e’s so whole the
# st)).).
#
# 'well, we )e’s will ))n? what will not )ty,' )gly are slowly the stream str)gked an)d), an). the company the dark ha)s of)-for
# the streams of his lore t)v’t)) the s)oved the answers of th)fbly and to)), but we brought i)e’s a)s an), in the st))erd! )wbuse messeng). 'the)-)gver wer
# ------ temperature: 1.0
# ’s a)s an), in the st))erd! )wbuse messeng). 'the)-)gver were a sky or not )e’st should filted end of you
# beauty and deeple called out, and yo). bewaring myse)), then g)und's and call good le)ed trailed )dcing earth
# fipes to pressed. )mm while an laugh wrathed his right: all harm the other that
# t)wf)bos wa)inses )wrock, but it and guarges). ')) you)! to stirr). 'whi)n! the de)e’s). but )ggs who while yes,, and really
# ove) even and grn was a)wbwar, iybl
# ------ temperature: 1.2
#  while yes,, and really
# ove) even and grn was a)wbwar, iyble)ee. nor will bron.?'
#
# 'it's vain) is coming wi), are le)abput)! , p)illi)gruosh, rid) he marded. ))owgrout: it was
# glemed
# fell.)w dil terese.
#
# 'bitter aro t)). )gking love! burts, it would endurrlyly.' ))).) done, nowing indeed; though
#
# rele ))e arent thun crall chang)ots ha), rowing.
#
# )n)ing clossed that us
# )wfirss.' h)bwava), the mor))wboul. 'so yes)-it who)eug, in f)ublignye! i finddd)
# epoch 23
# Epoch 1/1
# 278267/278267 [==============================] - 174s 624us/step - loss: 3.5450
# --- Generating with seed: "ippin, a terrific spurt it seemed for the end of a race. the"
# ------ temperature: 0.2
# ippin, a terrific spurt it seemed for the end of a race. there was not the stream and black
# and
# the stream was a
# stream and )nkes of the)wblest
# a)s the)w)bne.
#
# 'then some too the stream )n))ned to the stream and b)wbling and
# t)greme)or with the stream of) the stream and
# the stream of the
# arch of the sunlight of the stream and)e)e’s
# arm we)e’s and
# the)).
#
# 'i ))n we ))nwer.
#
# 'then the stream of the stre)t strider the stream of the
# stream.
#
# 'i w
# ------ temperature: 0.5
# ream of the stre)t strider the stream of the
# stream.
#
# 'i was th))s
# the
# together for
# the rope )dfolk and hill with the distly wrotted and stood the rohan the sign of the end.
#
# 'stripping )wbort have )cnes and)ing to him th))s stead)e!'
#
# 'we have
# way the silver of the stream of the rider, and for you
# ...
# ------ temperature: 1.0
# ie  a ae re o
#   a"eeoit i e e  iirree arehae r  rini o e aoe ei  aii   oirre ea a aier eire tri  orerae oa a iare reei  s o a ie ioie  ire tare 'e a ie a a  ae re eiti i  t hareaf ri  i aoeaie rie eeriie   ioi  oee ae ara e ab aee  ee ooree ae  ar ai eioe ta o    cae  9nore eane iaaie i eoae ®  e tra i s tu ee ea aar  eeferohire e  an ae si  orerier i  ae da  iniarie ii  a  iei ao e  eiioi   eo a  oiarn     ii iu e  o  iei oa aaire i ar oeio t a ae a a  ie
# ------ temperature: 1.2
#  oiarn     ii iu e  o  iei oa aaire i ar oeio t a ae a a  ie oi oia e ioo   are aoe  i reeiri  irie
# heii e oa ia a eerea  re ea a ae i  bo e e are e  o ra  are iir  ro i   ea in saere  a®ai  it  e erirea ei aa ar aiiu oi  eare ai t  ae  aa e ar   are roe er daeari ooer eiee a r a r t e  ro  e  e sar  e ier e a iiaoa aee ire eeea to   ai iiii  ieooaei  aoi ieiaorieai ea    ar  ire eee  iarr ee ooa
#  or dee ii ia ia ar i o a are oe erro a  oi  ar  iie a re
# epoch 47
# Epoch 1/1
# 278267/278267 [==============================] - 174s 625us/step - loss: 11.3560
# --- Generating with seed: " mountain. part of the name of this place might be wellingha"
# ------ temperature: 0.2
#  mountain. part of the name of this place might be wellingha areeeaaaaa are aa aea  aa   ae aaa aaaeraa  raa aas arre  ar  aaora  a  aa arareaara aa a   ara  are a aoa araraara araara   raa  ar  araa ar  ar are  aarare aie ra  are aarea ai aa ae ra  a aara ar are  ioae  are a reaoaaa raaraareaa a ar  a   a at a  area aaaaar rarar  aai a or a ra aaee s aa aa aaar  a ara arer a   areae ar aia  are  oaiaarararo area a aara  aeraaa a ar aareare aore ao aaairer
# ------ temperature: 0.5
# oaiaarararo area a aara  aeraaa a ar aareare aore ao aaaireraaraa  d  ee  ar  aeaaaare arroai aroa a are are aiare  ar a rar   a ara aae  a aoare aaa a a  ar aarre aa  ario i aor  ar  ar aora ai   re airoa areoo arareaiaa  aai ere aree a ara  ai a a ao ia ae a ara    aa aiara ara   arsaar  araar ar  ae  ar aaiarea aa  are  are aa  a ari ara aar  ar arare   a a an a a areoi area  area  ara  i  arare ae areae aaiai  erooi oe  aeara aaroa aa ro ai araaraa sar
# ------ temperature: 1.0
# e ae areae aaiai  erooi oe  aeara aaroa aa ro ai araaraa sar oa    a airra ea are  a aaeroe  ora  ao oar  a ro aao 1ia ei a aia  rar orarraar a ai  ar r aie i  ' oa e ie rara  araoa aa re  aarea a arraaraee iaeaara re  aai ao  i i ta oroiaa  e aa  ea eoaaraaeere arhee earearariereriae  o arere e ri aaoaraar ioa or ee ae aar yoa  aa  oar  re aa ae ariareoairi  ia eaa  e ae rooa ire aa ar ae aaeiaia    r oare orotiee aa os rara aoriar ari  aeearie rhai e  ar
# ------ temperature: 1.2
#     r oare orotiee aa os rara aoriar ari  aeearie rhai e  aree aai arai ireiiroai ararrairaai ea  oa e eaeo aar a aa  e arae  iaorareai  are e ia e to  ai a  ra ia ara  neoaa ioerreore oo i  e a  or io  arare e ai  aa  oa ariai  arai ai ai oo rae aoeio areoaora  aiiee e  e ar ae  ora ai orroaare  areoaara  aaore ae ie ai aa  ai  ooae aror aa rai  r a  iraa aiae ei ore  oa  are ooei  ie ee aoreoarea re
# ear ar  oroarotr  eaia a  oere se  oare  eaa  aaiaa
# epoch 48
# Epoch 1/1
# 278267/278267 [==============================] - 174s 626us/step - loss: 10.9273
# --- Generating with seed: "o towers
#
#
#
# j.r.r.toikien
#
#
#
#
#
# * book iii *
#
#
#
# chapter 1 "
# ------ temperature: 0.2
# o towers
#
#
#
# j.r.r.toikien
#
#
#
#
#
# * book iii *
#
#
#
# chapter 1  oioreieeroe oi oareo rire a re  or ai ai a ire  re  i oe ar raiooerore iareeooi ae a  ireei o r iierooeere ai are aoreriroor ore io oi i  oieo ooe aore  aro  ar rooo  a  re oae ar  erreerare roor a ereare or  orre oaior oe oior  aieoi a eroo  re aooe o a airere arrei  aree  ar re  or  ir  are oar oororeee e a e  air re a  aie airei ooa e are airo are  are  a  o araie ai ri ae ooi oeeriie ai  a  o
# ------ temperature: 0.5
#  are airo are  are  a  o araie ai ri ae ooi oeeriie ai  a  oa eae  eaa are oaree ia oire ai ri oa iere ie tooiioer ae ioi  ore aore    ie areeooare iori ia  oore ooire araerooroa a  ere e oa oari i ireorror a  airareorrooreioroore orooi oa oa eroa oiriie aori are are i oi orea e are ao  areiooaeeiohororoieieeir oe ooi ao a  ororee oa iia  aroe ar aa ai  er oarre ai ar ae oiee are ooa roorir areoe  aio ore ore ai oiooe ai e oio  eoo ae io ooea ere  foieeee
# ------ temperature: 1.0
#  aio ore ore ai oiooe ai e oio  eoo ae io ooea ere  foieeee iriei oi ia a  oe   arreo area oreea rea oi toi  roi ii arie ai aera  oa aieore oee iee oe oo orireari aro ora rea eoire aea t oaoi  heaoori ii aaroiaoi  oori e are iaa ioo oore   aioro e aa  oir  iora oire a ire ire ai eero  iooi e ie oa or oo  oorr oi oor oa o ii ari o o oi oi iro oi oro arooi  ar eoi a  irirea  oiroeoer ioreo oirie oaarireaiaioe eo oera  ei roii oi iere orereare oie oaro er rie
# ------ temperature: 1.2
# rireaiaioe eo oera  ei roii oi iere orereare oie oaro er rieaee  ii oiiri ia  arr ea aeaoire orere eoio oo o ooi aoe oio e o riiiaiaio  a  ao ai orioi e re a ar ai ore  ae aer oirroooe ooorio ooa oare io oeorae oai  aroa roa roroare ari ei aa iaeieeoo oi ori ee iee oi  io ai  oia aiia i eree eea  aare ioo aeroooie eer oere a  a  ooar  inaiiro eroiiaie ie or  oi   io ai i ooro arre oiie oe e  ara eooioe eeoe ooeiraioooeaee   ea a  oroe oa ariaa  i aiioea  i
# epoch 49
# Epoch 1/1
# 278267/278267 [==============================] - 174s 624us/step - loss: 10.9487
# --- Generating with seed: "ou have not found in your hunting, and that's brighter
# wits"
# ------ temperature: 0.2
# ou have not found in your hunting, and that's brighter
# witse oorere ooe a  aoooo  oeo  o eqeerere or aor  o a i a aa ooaa  ie i oa   a ar ieeeoe  ai i ae  aea  a ore  ore  ar ai o oe i ee o ie ooeeero a ai o ooo ore  ar  ie a oo a  ioq ae    ire oar  ae  ar  or ao e  oe re are  o oee oo ae ari oee  a are oo a  ooe a ao  ore o oqoa aee a  a aooe a reooai e  ie ior a a  ai ie i  oore ooere o  aieeee oa  ai  oorrer a io a  o  e areoo re   or aere ar oe o ae
# ------ temperature: 0.5
# e oa  ai  oorrer a io a  o  e areoo re   or aere ar oe o ae  oo  aa  o qor reee oro eereeoo oieaia ii aee  r ae oe oe ae oieraeioe oi aa or aoe  or  i a ooa  oae  oor  iqoi  ae  ii ea a aiae aiore a a e oo a  re e ie   ari o e ee eroooqea ae eoor o  oiee ooe oore  ioie o  a oro  ir ore ooe aea aria  ea ore ie oooar  aa aeroe ioii eair oii ro e ooa oe oooe oi are ori oa  aa   ai  a   ro ereao oaie  aro  ie  ai  roie arooe ii ee a  oa  oo  o ooee aoear re  i
# ------ temperature: 1.0
#  aro  ie  ai  roie arooe ii ee a  oa  oo  o ooee aoear re  ieaioo  aia  rore ae arare i i1  ea  i ie o  o i o  i i a ae iio i a ai ai oore raie ai oie erie ie ore rere  a e aie oe iear i  a  ooae ae ore ire i eioe iiie o i eei oe aa oeie ooa  i  aie ieaai aeioe oeoe ieiia  ia  ie arie ae ae ai  ae ii ie  are ai  ia i— io ae oe  ii oer  eoe oe rir rooo aroroar oaooaria oio  o ai ioo are oiooi e  ai i e roe  a riree oo iq  a i i e ae ieoe oo or oao  ar aoe i
# ------ temperature: 1.2
#  i e roe  a riree oo iq  a i i e ae ieoe oo or oao  ar aoe ie oi aa   oi  oaee i aoi  oe oreori i oare i i  aioioiii ao ir  raa or ao o    e aeie ori e  i e  eoe o eo raoee ei  i  oor aee ie  ai  ae i eaorooa  i eorr aaee  oai ae aereaa oqare ao  oe ai eeooae  e aie a eie  er  a aaiae ae i  ai oa  aa ere oio oi ar aei e ooi  iae ooreiri ao aie  o a  oroi oo  oiroe ii ao  i ao oa e i ooia  eroooe  iio aia oa   ae  ia ee aeaira e oe oero o oearo eaei e   air
# epoch 50
# Epoch 1/1
# 278267/278267 [==============================] - 174s 625us/step - loss: 10.8636
# --- Generating with seed: "ling about this place.' fie sniffed. 'and a smell, i
# fancy."
# ------ temperature: 0.2
# ling about this place.' fie sniffed. 'and a smell, i
# fancy. r  re  ar     ior e    ae  oie e oa  e  a re  a  o
#  s i g or grrer i  r ar a ee  e aa o  aae eee oe ae  ar   aere e  a e re al  i  a   a  a   aic  ra  n ae re eoeerle  a ai   a   a  e  o  eeeee a  a te e  a  ooi arr  a  oeer  orre  a  i  er e  ae
#   eai    an   orire e ae i  ar  rer    re  a  aeeer ai i  ao e rre  are    a  aat  or   tee a    ore  e  a  o   rere  i   a  e    t a f e are ee
# ------ temperature: 0.5
#    tee a    ore  e  a  o   rere  i   a  e    t a f e are ee rrr a or oe t     ore iee  a  ia re oaeee  are"oa   a  roo i awere  e  'aiee   r   r oaro oe  eaore  la a i  ere   a arer   iraiirea oo e a areii o a  o  o  i   aroe   oe re  a oa  a oee  ieo vrar oare iee ore  t ore  r aa oa     ro  ei ear    iei  a   teoore  ar ar  ea 're   ai ael   io r a i  r roaer    a  aa  i a  a   o  at o ba a are a   arr ae    o erha i arre    e ai i a    re  ie o
# a  araa
# ------ temperature: 1.0
# a   arr ae    o erha i arre    e ai i a    re  ie o
# a  araa  e  ie  i ie  rara j  e oo  ii i ae  or   aelaa e ae ae ier e  i ai ei  eo e e ioro   a  rori e o  ha  e   esore  er er oro ( eo iie  eroeo e    oai  ooe   a  ae   i oa er e e  oie  oro  iao  ori ieaoo eo  ora  o a oreere ia   a ie ae  oo  e  ao e ie ai  aa  e o  o   e  itere ari a ioov    oi a  t  ee o o   aioi a ae  a  a  eaa   a      ade 'oe ror
#   aoree  oa  i ra a ai  r a o  e aer eo    aa
# ------ temperature: 1.2
# de 'oe ror
#   aoree  oa  i ra a ai  r a o  e aer eo    aa   s leior  orero irae r  ae e  err ree itaaaae ioraeeeen  i i i ai ae   a ie  a o e
#   tea   o  r r e oo ao t i  i e a   rif oe ae i a ao a   e  i o r r  ei t ere  "ro ior   thei oai  reae  aaa    ro  i ao a oa  a ire ei o ao  i e o o o arr
#   a  er   a rara  re ii  oaor eie e  err  o  ro  era  oi    a      eree   e or       at ea r a e i a ce sa   e eer oe ier  a   eoeiao  i iae aiooae a   iee
# epoch 51
# Epoch 1/1
# 278267/278267 [==============================] - 173s 623us/step - loss: 11.0730
# --- Generating with seed: "died, within sight
# of the land of his home.'
#
# 'no more can"
# ------ temperature: 0.2
# died, within sight
# of the land of his home.'
#
# 'no more can  io aor  rea  e  a   t ioi he oe  ae  ai ae  ae ire a a  ar aa  ar ar  a e  iee re  rae ar a a  aa a arre aet ra  ai  ore  a   a  tore a ai ara aa ae  ai ai reo oai ar  ori o rereeo oi oi i ar a   io r   ae i i a  aar or  t aare a a   a toe  ai  i a arr  a ie  o ai   aeiaa  ae a a ae  irae arer re i areiora a  ai   ar a a  aeaiee a   aireai i a ao ea ai  aoi ar a a  ar ai ai a  eare arioio  re  a
# ------ temperature: 0.5
# eai i a ao ea ai  aoi ar a a  ar ai ai a  eare arioio  re  a oo  a  ie aare  ihearirera a  o  te eo a   i  ae  a  a iai a     a b   i t   o avi a     i an t aa  a oy ai
# a are a a  oi a   a eoi e io ae r a e  oar o a ae  a o i rer r ae i a  ioot  i a     aoi a   taateo  ee  oi i re arroreo  o e  ao ar ae aar ie i ea  o     he ai oe are  a oa re aiie aoro  arr  ar oie i  a   ®  r a  tooa  a io er ao  a aei  o ra aoi e  a  oa oi r  ar e  a a  i i i orio a
# ------ temperature: 1.0
# ao  a aei  o ra aoi e  a  oa oi r  ar e  a a  i i i orio a    ae  eoo    ar iiiea oi     i   a yoa  a rea ei   oafeoea a  r te  ei erior a  iri io ar oi i i e aroeer ea    a o eit or a aeoai ee  i oieaie  re   ai a   a  ae  orai or   ori a eoa   r oreooaiaa  ora a o aor eirrioooraroae oao a   o oe ai  o aoi eore i  e  io i a r a  o e    wa oi anoo  re eeii r aro areeee i  ai iiarooe   i i  a  io ro  oo ai aei oaao o i  e aee ra     aior  a ei i ere t  ae i
# ------ temperature: 1.2
# o  oo ai aei oaao o i  e aee ra     aior  a ei i ere t  ae i aroe  oro   ae o e aa eiii ar i a  ioea iei  ei or i aa irai a  a  rr  o   a o iar  eore  eo  a  aioere e ero eei o  ao ai  a aoa  ai  a oaree  e o a ooii" mo  oe oae  e iri r  ro  aa  a  a i o ai iro i a  a  i oiiari aaroeoi a a  ar a   i eiio   fe ae araii a  eoro  oi ioa aorea  a   e i eae ei  o ereero   eewae are   aai r   iioo iaorao ioe e iorar or i oe  ee iir aa  o   iri i ooeo e loe a  ee
# epoch 52
# Epoch 1/1
# 278267/278267 [==============================] - 174s 624us/step - loss: 11.0140
# --- Generating with seed: "
#
# 'five days ere i set out on this venture, eleven days ago "
# ------ temperature: 0.2
#
#
# 'five days ere i set out on this venture, eleven days ago  i  ae toeeei ae—a  aa r hreo  i a ar  mre ee t oeeee    ae se are  i ba  a te ai ar  are a  tee re ere  re  he re  aitorereea i a ore a  aee ai ieeo  aehe a rra   r o  ar  rieera ti  ieererehr a  re varre e ieer e ierere  aaeea a  aw aeorr rere  a  re eeeeeoo eee   aa ir are reeao i eo  a rre   at ia  "e ie   ha aa a;  a  ai a  ritie a eso aa a  riae oo ree re ie ieeeiae ae  or e e e  ee  a  a  a
# ------ temperature: 0.5
# so aa a  riae oo ree re ie ieeeiae ae  or e e e  ee  a  a  ari t aor   reeeoe imeiaee i ar a areee ir ree ae aei i ar i aoi oeire  are iae a  re eeoe ri ee i a   o ei re ae wihroerr  e  aia aiaoe ae oe ter ae reree  fe ee   aer oa  bree  a o aeee ei deai io ee  e  ie ae  r r e ore oai a  irrer hieie a ise     or ai  a aie oe fre a  oie  de i i    it e ’r ea arerro a  aa e i re ir a  e i ieerire ihr  aeree aa ae ao ora a  to  a e   ar ira ae ar  aa  are  a
# ------ temperature: 1.0
# r  aeree aa ae ao ora a  to  a e   ar ira ae ar  aa  are  a eriie eri  aitiiore ae a he rre a  aea a  ae ar  ei   ereeeeo eot ere a  oer e i oro  e  ge  e egeo a) oe oaioe  fa aireeteaaiar r  aowoa i ae  ao eraioi ai  hi e o ei  e ee  oi he oaa
#  ioe  a  ia  ia ere ro  e  iherae ra
#  aia  aoiiaeroraei ei ae iia a  ar i ior a i aa r o ree ao a aa oer   ore ai a   eef   e ta  a  it  arere ire ie  rra  te e tire ore a  r  aeie  arere   iehor  ewooe aieea  ia
# ------ temperature: 1.2
# a  te e tire ore a  r  aeie  arere   iehor  ewooe aieea  ia  o re   aadrri are o aroi   iee ai iai eri  ee   oaefee reare i e ioeereioe ea oo r    rr oeoar i    ta oaoeaa  t trrereriioe    iay   oe  i ve ar    teanre aire  rir  orae oeo ii  t u ire ei    earee rore    ii o o im ereoo eee iai arrea a  a e aie r  aiea a  ieraero  ea eoiaa eei oe oa ao  e   arei i i eitoerre ee eai oee  sar aoi go i te iei ore  eaioa raiee e  ’raar aai  eioi rri ea er era  e
# epoch 53
# Epoch 1/1
# 278267/278267 [==============================] - 174s 625us/step - loss: 11.0035
# --- Generating with seed: "still!'
#
# gollum went limp, and began to whine and weep. the"
# ------ temperature: 0.2
# still!'
#
# gollum went limp, and began to whine and weep. ther a  eee ae ae e aoe e e reeae ooereeeee erea  es eeeeere  ee ore ae oee  av a re e ae a re re    irer  rere aeore  ire  e   oee a  eteae e;  o   oee aeeeae aceorere  eee a ae a  a oe   aoeee a e a  e aee eoe aa errse area e ae a  ae ee  oeeare ee oree  eeae   ar ar r ae area  a rer a e  oere ai ereeeere a  e   an a  aee aere ie  oe aeee    eeeereereeae eoee  er  a   baree a aeraee ae veai ee  oe
# ------ temperature: 0.5
#    eeeereereeae eoee  er  a   baree a aeraee ae veai ee  oe ae ae a a   e  eeee eaaea eeee arioe   or  oi a re ae aer ar ar re eao ae  err oee eee  ae aire ar ao are aor  eor  ir    oaore oe oar eee  ore ri ero aere rea  a ar ore  a oe  a erare eree ae oe ee t a a    ai  eo rr oar  re   ere o  ae ioerre ai ae ee  oe ree  eoeer eiooeeererer o ae   ser  aree  ear ae oe i e a aor aereeoreeereee eer  o  o aeere  a  re o ar  e ai  aeaee e   iooo e oee ere   nej
# ------ temperature: 1.0
# o  o aeere  a  re o ar  e ai  aeaee e   iooo e oee ere   nej i !  i aean iere ee ioaie  aeeeee ar o a ao e a i aii rr   o earaaerooaae ieo ie je  e areeere o ieire are iiero iree ie e  ae a i aar rire  i e be oi a oa ereeoarreaeraoeei oe e  e  eeir  ee   a  i   boor  o  ha e i t  aor r a s ariaoireeee ioee  rea  rerereeae c e  roo oaaioiai ie arii re io ri ere  oe  oe i aaoeoe  e  ieae oere  ir i a  aoeea eeee ire a eee  ieee  or oee aei a  i ereeooeeoiea
# ------ temperature: 1.2
# a  aoeea eeee ire a eee  ieee  or oee aei a  i ereeooeeoiea aae aeeari ae era   oe  e rea aoeeeo eaiee e ee    e e aroie i   a i oeo i oeer roeoea  ieerioa ei    orear ere eie   iioiier e riira ori i aioo aer a    rorierer  aeairii aeai aiee  e a  enere eoaeoi a  r   eaeee ioera aeeroo arer ai oi io ea ee oe a  i aeeeoar rorr a io oori ireei er  aee a a e  ae ai ee ae ari eha  o aro eoor re  e  eo eoai  eo ai aareai aee oeioero eaar  ri e bire  teo oi  eei
# epoch 54
# Epoch 1/1
#  81408/278267 [=======>......................] - ETA: 2:02 - loss: 9.9249

# %% [markdown]
# ### Model 2

# %%
# Length of extracted character sequences
maxlen = 100

# We sample a new sequence every `step` characters
step = 5

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 166952
# Unique characters: 58
# Vectorization...

# %%
from keras import layers
from keras import regularizers

model2 = keras.models.Sequential()
model2.add(layers.LSTM(128, input_shape=(maxlen, len(chars)))) 
model2.add(layers.Dense(len(chars), activation='softmax'))

# %%
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 128)               95744
# _________________________________________________________________
# dense_3 (Dense)              (None, 58)                7482
# =================================================================
# Total params: 103,226
# Trainable params: 103,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model2.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
import random
import sys

for epoch in range(1, 25):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model2.fit(x, y,
              batch_size=128,
              epochs=1)
    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# InternalError: GPU sync failed
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-20-bc3f1211a349> in <module>()
#       7     model2.fit(x, y,
#       8               batch_size=128,
# ----> 9               epochs=1)
#      10     # Select a text seed at random
#      11     start_index = random.randint(0, len(text) - maxlen - 1)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     961                               initial_epoch=initial_epoch,
#     962                               steps_per_epoch=steps_per_epoch,
# --> 963                               validation_steps=validation_steps)
#     964
#     965     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2474             feed_dict[tensor] = value
#    2475         fetches = self.outputs + [self.updates_op] + self.fetches
# -> 2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
#    2478                               **self.session_kwargs)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     190                 # not already marked as initialized.
#     191                 is_initialized = session.run(
# --> 192                     [tf.is_variable_initialized(v) for v in candidate_vars])
#     193                 uninitialized_vars = []
#     194                 for flag, v in zip(is_initialized, candidate_vars):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# InternalError: GPU sync failed
